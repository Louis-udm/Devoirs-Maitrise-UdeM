# %%
from __future__ import print_function

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn

import torchvision
import torchvision.transforms as transforms
import torch.utils.data.sampler as sampler
import torchvision.datasets as datasets

import os
import numpy as np

import matplotlib.pyplot as plt
from PIL import Image
#import argparse

#from models import *
from torch.autograd import Variable
import vgg

# %%
print(os.getcwd())

'''
# Set hyper parameters.
'''
IMAGES_ROOT = 'datasets/PetImages'
MY_TEST_ROOT = 'datasets/my_test'
MODEL_SAVE_PATH='output'
MODEL_SAVE_INTERVAL = 5

# hyper parameters of Deep learning
IMAGE_RESIZE=64
TRAIN_SIZE = 16000
VALID_SIZE = 4000
TEST_SIZE = 4990
EPOCH_NUM = 100
BATCH_SIZE_TRAIN=25
BATCH_SIZE_VALID=50
BATCH_SIZE_TEST = 16
LR_0=0.1
MOMENTUM=0.9
WEIGHT_DECAY=5e-4
resume = False
best_acc = 0

cuda_available = torch.cuda.is_available()
# Out:
# /Users/fanxiao/Downloads/Xiao_Fan/20180304

# %% [markdown]
# ## Load the dog_vs_cat data

# %%
indices = list(range(TRAIN_SIZE+VALID_SIZE+TEST_SIZE))
np.random.seed(123)
np.random.shuffle(indices)

train_idx, valid_idx, test_idx = indices[:TRAIN_SIZE], indices[TRAIN_SIZE:(TRAIN_SIZE+VALID_SIZE)], indices[(TRAIN_SIZE+VALID_SIZE):]

train_sampler = sampler.SubsetRandomSampler(train_idx)
valid_sampler = sampler.SubsetRandomSampler(valid_idx)
test_sampler = sampler.SubsetRandomSampler(test_idx)

data_transform = transforms.Compose([
    transforms.Resize((IMAGE_RESIZE, IMAGE_RESIZE), interpolation=Image.BILINEAR),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    # transforms.Normalize(mean=[0], std=[1])
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[
                            0.229, 0.224, 0.225])
])
dataset = datasets.ImageFolder(root=IMAGES_ROOT, transform=data_transform)

train_data_loader = torch.utils.data.DataLoader(
    dataset, batch_size=BATCH_SIZE_TRAIN, sampler=train_sampler, num_workers=10)

valid_data_loader = torch.utils.data.DataLoader(
    dataset, batch_size=BATCH_SIZE_VALID,  sampler=valid_sampler, num_workers=10)

test_data_loader = torch.utils.data.DataLoader(
    dataset, batch_size=BATCH_SIZE_TEST,  sampler=test_sampler, num_workers=10)

my_testset = datasets.ImageFolder(root=MY_TEST_ROOT, transform=data_transform)

my_data_loader = torch.utils.data.DataLoader(
    my_testset, batch_size=BATCH_SIZE_VALID, shuffle=False, num_workers=10)

print('Loaded images(train and valid), total',len(train_sampler)+len(valid_sampler))
print('Loaded test images, total',len(test_sampler))
print('Image size: ', dataset[0][0].size())
# Out:
# Loaded images(train and valid), total 20000
# Loaded test images, total 4990
# Image size:  torch.Size([3, 64, 64])

# %% [markdown]
# ## Build the model

# %%
# Training
def train(train_loader, model, criterion, optimizer, epoch):
    model.train()
    train_loss = 0
    correct = 0
    total = 0
    for batch_idx, (inputs, targets) in enumerate(train_loader):
        if cuda_available:
            inputs, targets = inputs.cuda(), targets.cuda()
        optimizer.zero_grad()
        inputs, targets = Variable(inputs), Variable(targets)
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()

        train_loss += loss.data[0]
        _, predicted = torch.max(outputs.data, 1)
        total += targets.size(0)
        correct += predicted.eq(targets.data).cpu().sum()
        train_acc = correct/total

#        utils.progress_bar(batch_idx, len(train_data_loader), 'Loss: %.3f | Acc: %.3f%% (%d/%d)'
#            % (train_loss/(batch_idx+1), 100.*correct/total, correct, total))
    
    print('Epoch : %d, Train Acc : %.3f' % (epoch, 100.*train_acc))
#            print('--------------------------------------------------------------')
    return train_acc
    
# evaluate
def evaluate(valid_loader, model, criterion, epoch, path = './checkpoint/vgg16'):
    global best_acc
    model.eval()
    test_loss = 0
    correct = 0
    total = 0
    for batch_idx, (inputs, targets) in enumerate(valid_loader):
        if cuda_available:
            inputs, targets = inputs.cuda(), targets.cuda()
        inputs, targets = Variable(inputs, volatile=True), Variable(targets)
        outputs = model(inputs)
        loss = criterion(outputs, targets)

        test_loss += loss.data[0]
        _, predicted = torch.max(outputs.data, 1)
        total += targets.size(0)
        correct += predicted.eq(targets.data).cpu().sum()
        test_acc = correct/total

    print('Epoch : %d, Valid Acc : %.3f' % (epoch, 100.*test_acc))
    print('--------------------------------------------------------------')

    # Save checkpoint.
    acc = 100.*correct/total
    if acc > best_acc:
        print('Saving..')
        state = {
            'net': model.module if cuda_available else model,
            'acc': acc,
            'epoch': epoch,
        }
        if not os.path.isdir('checkpoint'):
            os.mkdir('checkpoint')
        torch.save(state, path)
        best_acc = acc
        
    return test_acc

# test
def test(test_loader, model):
    model.eval()
    test_loss = 0
    correct = 0
    total = 0
    for batch_idx, (inputs, targets) in enumerate(test_loader):
        if cuda_available:
            inputs, targets = inputs.cuda(), targets.cuda()
        inputs, targets = Variable(inputs, volatile=True), Variable(targets)
        outputs = model(inputs)
        loss = criterion(outputs, targets)

        test_loss += loss.data[0]
        _, predicted = torch.max(outputs.data, 1)
        total += targets.size(0)
        correct += predicted.eq(targets.data).cpu().sum()
        test_acc = correct/total

    print('Test Acc : %.3f' % ( 100.*test_acc))


def adjust_lr(optimizer, epoch, total_epochs):
    lr = LR_0 * (0.1 ** (epoch / float(total_epochs)))
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

#model = train_model(dloaders, net, criterion, optimizer, exp_lr_scheduler, num_epochs=2)
#print('Training time: {:10f} minutes'.format((time.time()-start_time)/60))

def train_model(model, train_loader, valid_loader, criterion, optimizer, num_epochs=25, path = './checkpoint/vgg16') :
    train_acc_list=[]
    valid_acc_list=[]
    for epoch in range(0, num_epochs):
        train_acc_list.append(train(train_loader, model, criterion, optimizer, epoch))
        adjust_lr(optimizer,epoch,num_epochs)
        valid_acc_list.append(evaluate(valid_loader, model, criterion, epoch, path))
    return train_acc_list, valid_acc_list

# %%
if resume==False : 
    train_acc_list = []
    valid_acc_list = []
for epoch in range(0, EPOCH_NUM):
    train_acc_list.append(train(epoch))
    adjust_lr(optimizer,epoch,EPOCH_NUM)
    valid_acc_list.append(evaluate(epoch,valid_data_loader))
# Out:
# Epoch : 0, Train Acc : 51.700
# Epoch : 0, Test Acc : 51.350
# --------------------------------------------------------------
# Saving..
# Epoch : 1, Train Acc : 52.050
# Epoch : 1, Test Acc : 51.875
# --------------------------------------------------------------
# Saving..
# Epoch : 2, Train Acc : 52.375
# Epoch : 2, Test Acc : 52.525
# --------------------------------------------------------------
# Saving..
# Epoch : 3, Train Acc : 51.663
# Epoch : 3, Test Acc : 52.125
# --------------------------------------------------------------
# Epoch : 4, Train Acc : 52.819
# Epoch : 4, Test Acc : 53.600
# --------------------------------------------------------------
# Saving..
# Epoch : 5, Train Acc : 54.825
# Epoch : 5, Test Acc : 56.250
# --------------------------------------------------------------
# Saving..
# Epoch : 6, Train Acc : 56.087
# Epoch : 6, Test Acc : 50.150
# --------------------------------------------------------------
# Epoch : 7, Train Acc : 61.544
# Epoch : 7, Test Acc : 65.600
# --------------------------------------------------------------
# Saving..
# Epoch : 8, Train Acc : 65.500
# Epoch : 8, Test Acc : 58.150
# --------------------------------------------------------------
# Epoch : 9, Train Acc : 69.219
# Epoch : 9, Test Acc : 69.325
# --------------------------------------------------------------
# Saving..
# Epoch : 10, Train Acc : 71.950
# Epoch : 10, Test Acc : 64.750
# --------------------------------------------------------------
# Epoch : 11, Train Acc : 73.531
# Epoch : 11, Test Acc : 72.400
# --------------------------------------------------------------
# Saving..
# Epoch : 12, Train Acc : 77.406
# Epoch : 12, Test Acc : 72.125
# --------------------------------------------------------------
# Epoch : 13, Train Acc : 79.719
# Epoch : 13, Test Acc : 71.300
# --------------------------------------------------------------
# Epoch : 14, Train Acc : 81.819
# Epoch : 14, Test Acc : 80.150
# --------------------------------------------------------------
# Saving..
# Epoch : 15, Train Acc : 84.044
# Epoch : 15, Test Acc : 80.750
# --------------------------------------------------------------
# Saving..
# Epoch : 16, Train Acc : 84.894
# Epoch : 16, Test Acc : 72.825
# --------------------------------------------------------------
# Epoch : 17, Train Acc : 85.638
# Epoch : 17, Test Acc : 86.550
# --------------------------------------------------------------
# Saving..
# Epoch : 18, Train Acc : 86.644
# Epoch : 18, Test Acc : 79.100
# --------------------------------------------------------------
# Epoch : 19, Train Acc : 87.425
# Epoch : 19, Test Acc : 78.300
# --------------------------------------------------------------
# Epoch : 20, Train Acc : 87.537
# Epoch : 20, Test Acc : 86.675
# --------------------------------------------------------------
# Saving..
# Epoch : 21, Train Acc : 87.869
# Epoch : 21, Test Acc : 82.650
# --------------------------------------------------------------
# Epoch : 22, Train Acc : 88.669
# Epoch : 22, Test Acc : 81.975
# --------------------------------------------------------------
# Epoch : 23, Train Acc : 89.650
# Epoch : 23, Test Acc : 77.925
# --------------------------------------------------------------
# Epoch : 24, Train Acc : 89.231
# Epoch : 24, Test Acc : 82.125
# --------------------------------------------------------------
# Epoch : 25, Train Acc : 89.606
# Epoch : 25, Test Acc : 84.975
# --------------------------------------------------------------
# Epoch : 26, Train Acc : 89.737
# Epoch : 26, Test Acc : 87.700
# --------------------------------------------------------------
# Saving..
# Epoch : 27, Train Acc : 89.575
# Epoch : 27, Test Acc : 74.900
# --------------------------------------------------------------
# Epoch : 28, Train Acc : 90.556
# Epoch : 28, Test Acc : 89.300
# --------------------------------------------------------------
# Saving..
# Epoch : 29, Train Acc : 91.344
# Epoch : 29, Test Acc : 90.500
# --------------------------------------------------------------
# Saving..
# Epoch : 30, Train Acc : 91.669
# Epoch : 30, Test Acc : 84.400
# --------------------------------------------------------------
# Epoch : 31, Train Acc : 91.594
# Epoch : 31, Test Acc : 83.500
# --------------------------------------------------------------
# Epoch : 32, Train Acc : 91.500
# Epoch : 32, Test Acc : 89.100
# --------------------------------------------------------------
# Epoch : 33, Train Acc : 91.744
# Epoch : 33, Test Acc : 88.100
# --------------------------------------------------------------
# Epoch : 34, Train Acc : 91.838
# Epoch : 34, Test Acc : 89.675
# --------------------------------------------------------------
# Epoch : 35, Train Acc : 91.987
# Epoch : 35, Test Acc : 88.750
# --------------------------------------------------------------
# Epoch : 36, Train Acc : 91.994
# Epoch : 36, Test Acc : 90.150
# --------------------------------------------------------------
# Epoch : 37, Train Acc : 92.700
# Epoch : 37, Test Acc : 89.675
# --------------------------------------------------------------
# Epoch : 38, Train Acc : 92.588
# Epoch : 38, Test Acc : 89.400
# --------------------------------------------------------------
# Epoch : 39, Train Acc : 93.069
# Epoch : 39, Test Acc : 80.900
# --------------------------------------------------------------
# Epoch : 40, Train Acc : 93.331
# Epoch : 40, Test Acc : 90.900
# --------------------------------------------------------------
# Saving..
# Epoch : 41, Train Acc : 93.131
# Epoch : 41, Test Acc : 90.450
# --------------------------------------------------------------
# Epoch : 42, Train Acc : 93.944
# Epoch : 42, Test Acc : 91.075
# --------------------------------------------------------------
# Saving..
# Epoch : 43, Train Acc : 93.706
# Epoch : 43, Test Acc : 86.700
# --------------------------------------------------------------
# Epoch : 44, Train Acc : 93.425
# Epoch : 44, Test Acc : 88.650
# --------------------------------------------------------------
# Epoch : 45, Train Acc : 94.081
# Epoch : 45, Test Acc : 92.325
# --------------------------------------------------------------
# Saving..
# Epoch : 46, Train Acc : 94.119
# Epoch : 46, Test Acc : 90.975
# --------------------------------------------------------------
# Epoch : 47, Train Acc : 93.850
# Epoch : 47, Test Acc : 91.200
# --------------------------------------------------------------
# Epoch : 48, Train Acc : 94.337
# Epoch : 48, Test Acc : 91.150
# --------------------------------------------------------------
# Epoch : 49, Train Acc : 94.725
# Epoch : 49, Test Acc : 89.775
# --------------------------------------------------------------
# Epoch : 50, Train Acc : 94.312
# Epoch : 50, Test Acc : 88.325
# --------------------------------------------------------------
# Epoch : 51, Train Acc : 94.837
# Epoch : 51, Test Acc : 89.600
# --------------------------------------------------------------
# Epoch : 52, Train Acc : 94.769
# Epoch : 52, Test Acc : 90.375
# --------------------------------------------------------------
# Epoch : 53, Train Acc : 94.981
# Epoch : 53, Test Acc : 91.775
# --------------------------------------------------------------
# Epoch : 54, Train Acc : 95.081
# Epoch : 54, Test Acc : 91.500
# --------------------------------------------------------------
# Epoch : 55, Train Acc : 95.144
# Epoch : 55, Test Acc : 92.550
# --------------------------------------------------------------
# Saving..
# Epoch : 56, Train Acc : 95.206
# Epoch : 56, Test Acc : 90.775
# --------------------------------------------------------------
# Epoch : 57, Train Acc : 95.337
# Epoch : 57, Test Acc : 91.300
# --------------------------------------------------------------
# Epoch : 58, Train Acc : 95.688
# Epoch : 58, Test Acc : 89.950
# --------------------------------------------------------------
# Epoch : 59, Train Acc : 95.669
# Epoch : 59, Test Acc : 92.275
# --------------------------------------------------------------
# Epoch : 60, Train Acc : 95.644
# Epoch : 60, Test Acc : 91.575
# --------------------------------------------------------------
# Epoch : 61, Train Acc : 95.837
# Epoch : 61, Test Acc : 85.500
# --------------------------------------------------------------
# Epoch : 62, Train Acc : 96.025
# Epoch : 62, Test Acc : 92.100
# --------------------------------------------------------------
# Epoch : 63, Train Acc : 96.275
# Epoch : 63, Test Acc : 91.200
# --------------------------------------------------------------
# Epoch : 64, Train Acc : 96.462
# Epoch : 64, Test Acc : 91.600
# --------------------------------------------------------------
# Epoch : 65, Train Acc : 96.575
# Epoch : 65, Test Acc : 92.850
# --------------------------------------------------------------
# Saving..
# Epoch : 66, Train Acc : 96.394
# Epoch : 66, Test Acc : 93.075
# --------------------------------------------------------------
# Saving..
# Epoch : 67, Train Acc : 96.650
# Epoch : 67, Test Acc : 91.675
# --------------------------------------------------------------
# Epoch : 68, Train Acc : 96.688
# Epoch : 68, Test Acc : 91.200
# --------------------------------------------------------------
# Epoch : 69, Train Acc : 97.006
# Epoch : 69, Test Acc : 91.450
# --------------------------------------------------------------
# Epoch : 70, Train Acc : 96.950
# Epoch : 70, Test Acc : 92.425
# --------------------------------------------------------------
# Epoch : 71, Train Acc : 97.000
# Epoch : 71, Test Acc : 92.625
# --------------------------------------------------------------
# Epoch : 72, Train Acc : 97.112
# Epoch : 72, Test Acc : 93.325
# --------------------------------------------------------------
# Saving..
# Epoch : 73, Train Acc : 97.138
# Epoch : 73, Test Acc : 90.550
# --------------------------------------------------------------
# Epoch : 74, Train Acc : 97.069
# Epoch : 74, Test Acc : 93.150
# --------------------------------------------------------------
# Epoch : 75, Train Acc : 97.325
# Epoch : 75, Test Acc : 92.825
# --------------------------------------------------------------
# Epoch : 76, Train Acc : 97.456
# Epoch : 76, Test Acc : 92.925
# --------------------------------------------------------------
# Epoch : 77, Train Acc : 97.481
# Epoch : 77, Test Acc : 92.975
# --------------------------------------------------------------
# Epoch : 78, Train Acc : 97.513
# Epoch : 78, Test Acc : 90.725
# --------------------------------------------------------------
# Epoch : 79, Train Acc : 97.381
# Epoch : 79, Test Acc : 92.375
# --------------------------------------------------------------
# Epoch : 80, Train Acc : 97.706
# Epoch : 80, Test Acc : 86.750
# --------------------------------------------------------------
# Epoch : 81, Train Acc : 97.619
# Epoch : 81, Test Acc : 92.900
# --------------------------------------------------------------
# Epoch : 82, Train Acc : 98.019
# Epoch : 82, Test Acc : 93.150
# --------------------------------------------------------------
# Epoch : 83, Train Acc : 97.656
# Epoch : 83, Test Acc : 93.025
# --------------------------------------------------------------
# Epoch : 84, Train Acc : 97.812
# Epoch : 84, Test Acc : 92.925
# --------------------------------------------------------------
# Epoch : 85, Train Acc : 97.944
# Epoch : 85, Test Acc : 92.525
# --------------------------------------------------------------
# Epoch : 86, Train Acc : 98.294
# Epoch : 86, Test Acc : 93.950
# --------------------------------------------------------------
# Saving..
# Epoch : 87, Train Acc : 98.025
# Epoch : 87, Test Acc : 88.550
# --------------------------------------------------------------
# Epoch : 88, Train Acc : 98.381
# Epoch : 88, Test Acc : 93.350
# --------------------------------------------------------------
# Epoch : 89, Train Acc : 98.100
# Epoch : 89, Test Acc : 91.700
# --------------------------------------------------------------
# Epoch : 90, Train Acc : 98.237
# Epoch : 90, Test Acc : 92.750
# --------------------------------------------------------------
# Epoch : 91, Train Acc : 98.275
# Epoch : 91, Test Acc : 93.400
# --------------------------------------------------------------
# Epoch : 92, Train Acc : 98.300
# Epoch : 92, Test Acc : 90.075
# --------------------------------------------------------------
# Epoch : 93, Train Acc : 98.494
# Epoch : 93, Test Acc : 88.900
# --------------------------------------------------------------
# Epoch : 94, Train Acc : 98.600
# Epoch : 94, Test Acc : 92.450
# --------------------------------------------------------------
# Epoch : 95, Train Acc : 98.319
# Epoch : 95, Test Acc : 93.050
# --------------------------------------------------------------
# Epoch : 96, Train Acc : 98.550
# Epoch : 96, Test Acc : 93.325
# --------------------------------------------------------------
# Epoch : 97, Train Acc : 98.537
# Epoch : 97, Test Acc : 93.000
# --------------------------------------------------------------
# Epoch : 98, Train Acc : 98.969
# Epoch : 98, Test Acc : 92.550
# --------------------------------------------------------------
# Epoch : 99, Train Acc : 98.819
# Epoch : 99, Test Acc : 92.775
# --------------------------------------------------------------

# %%
plt.figure()
plt.plot(range(0,EPOCH_NUM),train_acc_list,label='Training')
plt.plot(range(0,EPOCH_NUM),valid_acc_list,label='Validation')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# plt.savefig('problem2-accuracy1.pdf')

# %%
# Load checkpoint.
criterion = nn.CrossEntropyLoss()
print('==> Resuming from checkpoint..')
assert os.path.isdir('checkpoint'), 'Error: no checkpoint directory found!'
checkpoint = torch.load('./checkpoint/vgg16_2')
net = checkpoint['net']
best_acc = checkpoint['acc']
start_epoch = checkpoint['epoch']
print ('Best validation acc : %.3f' % (best_acc))
test(test_data_loader, net)
# Out:
# ==> Resuming from checkpoint..
# Best validation acc : 93.950
# Test Acc : 93.808

# %% [markdown]
# ## VGG16 use Adam

# %%
LR_0=0.1
MOMENTUM=0.9
WEIGHT_DECAY=7e-4

print('==> Building model..')
net = vgg.VGG('VGG16')

if cuda_available:
    net.cuda()
    net = torch.nn.DataParallel(net, device_ids=range(torch.cuda.device_count()))
    cudnn.benchmark = True
    
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=LR_0, weight_decay=WEIGHT_DECAY)
# Out:
# ==> Building model..

# %%
if resume==False : 
    train_acc_list = []
    valid_acc_list = []
for epoch in range(0, EPOCH_NUM):
    train_acc_list.append(train(epoch))
    adjust_lr(optimizer,epoch,EPOCH_NUM)
    valid_acc_list.append(evaluate(epoch,valid_data_loader))
# Out:
# Epoch : 0, Train Acc : 50.550
# Epoch : 0, Test Acc : 48.650
# --------------------------------------------------------------
# Epoch : 1, Train Acc : 50.344
# Epoch : 1, Test Acc : 48.650
# --------------------------------------------------------------
# Epoch : 2, Train Acc : 49.394
# Epoch : 2, Test Acc : 51.350
# --------------------------------------------------------------
# Epoch : 3, Train Acc : 50.600
# Epoch : 3, Test Acc : 48.650
# --------------------------------------------------------------
# Epoch : 4, Train Acc : 50.844
# Epoch : 4, Test Acc : 48.650
# --------------------------------------------------------------
# Epoch : 5, Train Acc : 50.625
# Epoch : 5, Test Acc : 51.350
# --------------------------------------------------------------
# Epoch : 6, Train Acc : 50.525
# Epoch : 6, Test Acc : 48.650
# --------------------------------------------------------------
# Epoch : 7, Train Acc : 50.519
# Epoch : 7, Test Acc : 48.650
# --------------------------------------------------------------
# Epoch : 8, Train Acc : 49.712
# Epoch : 8, Test Acc : 51.350
# --------------------------------------------------------------
# Epoch : 9, Train Acc : 49.419
# Epoch : 9, Test Acc : 48.650
# --------------------------------------------------------------
# Epoch : 10, Train Acc : 49.875
# Epoch : 10, Test Acc : 48.650
# --------------------------------------------------------------
# Epoch : 11, Train Acc : 50.400
# Epoch : 11, Test Acc : 48.650
# --------------------------------------------------------------
# Epoch : 12, Train Acc : 49.781
# Epoch : 12, Test Acc : 51.350
# --------------------------------------------------------------
# Epoch : 13, Train Acc : 50.219
# Epoch : 13, Test Acc : 48.650
# --------------------------------------------------------------
# Epoch : 14, Train Acc : 50.100
# Epoch : 14, Test Acc : 51.350
# --------------------------------------------------------------
# Epoch : 15, Train Acc : 50.538
# Epoch : 15, Test Acc : 51.350
# --------------------------------------------------------------
# Epoch : 16, Train Acc : 49.150
# Epoch : 16, Test Acc : 48.650
# --------------------------------------------------------------
# Epoch : 17, Train Acc : 50.138
# Epoch : 17, Test Acc : 51.350
# --------------------------------------------------------------
# Epoch : 18, Train Acc : 50.331
# Epoch : 18, Test Acc : 51.350
# --------------------------------------------------------------
# Epoch : 19, Train Acc : 50.044
# Epoch : 19, Test Acc : 51.350
# --------------------------------------------------------------
# Epoch : 20, Train Acc : 50.606
# Epoch : 20, Test Acc : 48.650
# --------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-8220528fa849> in <module>()
#       3     valid_acc_list = []
#       4 for epoch in range(0, EPOCH_NUM):
# ----> 5     train_acc_list.append(train(epoch))
#       6     adjust_lr(optimizer,epoch,EPOCH_NUM)
#       7     valid_acc_list.append(test(epoch))
#
# <ipython-input-16-dba4711a3269> in train(ep, display)
#      38
#      39         train_loss += loss.data[0]
# ---> 40         _, predicted = torch.max(outputs.data, 1)
#      41         total += targets.size(0)
#      42         correct += predicted.eq(targets.data).cpu().sum()
#
# KeyboardInterrupt:

# %%
LR_0=0.1
MOMENTUM=0.9
WEIGHT_DECAY=7e-4

print('==> Building model..')
net = vgg.VGG('VGG16')

if cuda_available:
    net.cuda()
    net = torch.nn.DataParallel(net, device_ids=range(torch.cuda.device_count()))
    cudnn.benchmark = True
    
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=LR_0, momentum = MOMENTUM, weight_decay=WEIGHT_DECAY)
# Out:
# ==> Building model..

# %%
if resume==False : 
    train_acc_list = []
    valid_acc_list = []
for epoch in range(0, EPOCH_NUM):
    train_acc_list.append(train(epoch))
    adjust_lr(optimizer,epoch,EPOCH_NUM)
    valid_acc_list.append(evaluate(epoch,valid_data_loader))
# Out:
# Epoch : 0, Train Acc : 50.456
# Epoch : 0, Test Acc : 48.700
# --------------------------------------------------------------
# Epoch : 1, Train Acc : 50.844
# Epoch : 1, Test Acc : 49.275
# --------------------------------------------------------------
# Epoch : 2, Train Acc : 50.644
# Epoch : 2, Test Acc : 51.350
# --------------------------------------------------------------
# Epoch : 3, Train Acc : 51.462
# Epoch : 3, Test Acc : 51.350
# --------------------------------------------------------------
# Epoch : 4, Train Acc : 51.206
# Epoch : 4, Test Acc : 53.500
# --------------------------------------------------------------
# Epoch : 5, Train Acc : 54.181
# Epoch : 5, Test Acc : 53.225
# --------------------------------------------------------------
# Epoch : 6, Train Acc : 55.594
# Epoch : 6, Test Acc : 57.925
# --------------------------------------------------------------
# Epoch : 7, Train Acc : 59.169
# Epoch : 7, Test Acc : 64.950
# --------------------------------------------------------------
# Epoch : 8, Train Acc : 64.625
# Epoch : 8, Test Acc : 65.600
# --------------------------------------------------------------
# Epoch : 9, Train Acc : 68.519
# Epoch : 9, Test Acc : 62.550
# --------------------------------------------------------------
# Epoch : 10, Train Acc : 71.306
# Epoch : 10, Test Acc : 71.250
# --------------------------------------------------------------
# Epoch : 11, Train Acc : 72.850
# Epoch : 11, Test Acc : 74.800
# --------------------------------------------------------------
# Epoch : 12, Train Acc : 75.388
# Epoch : 12, Test Acc : 76.650
# --------------------------------------------------------------
# Epoch : 13, Train Acc : 76.675
# Epoch : 13, Test Acc : 74.775
# --------------------------------------------------------------
# Epoch : 14, Train Acc : 79.481
# Epoch : 14, Test Acc : 69.875
# --------------------------------------------------------------
# Epoch : 15, Train Acc : 81.487
# Epoch : 15, Test Acc : 72.025
# --------------------------------------------------------------
# Epoch : 16, Train Acc : 82.519
# Epoch : 16, Test Acc : 83.250
# --------------------------------------------------------------
# Epoch : 17, Train Acc : 83.944
# Epoch : 17, Test Acc : 84.875
# --------------------------------------------------------------
# Epoch : 18, Train Acc : 85.306
# Epoch : 18, Test Acc : 74.525
# --------------------------------------------------------------
# Epoch : 19, Train Acc : 85.706
# Epoch : 19, Test Acc : 86.225
# --------------------------------------------------------------
# Epoch : 20, Train Acc : 85.906
# Epoch : 20, Test Acc : 77.825
# --------------------------------------------------------------
# Epoch : 21, Train Acc : 86.644
# Epoch : 21, Test Acc : 85.875
# --------------------------------------------------------------
# Epoch : 22, Train Acc : 87.206
# Epoch : 22, Test Acc : 85.475
# --------------------------------------------------------------
# Epoch : 23, Train Acc : 87.269
# Epoch : 23, Test Acc : 72.500
# --------------------------------------------------------------
# Epoch : 24, Train Acc : 86.975
# Epoch : 24, Test Acc : 85.850
# --------------------------------------------------------------
# Epoch : 25, Train Acc : 87.787
# Epoch : 25, Test Acc : 80.250
# --------------------------------------------------------------
# Epoch : 26, Train Acc : 88.819
# Epoch : 26, Test Acc : 86.750
# --------------------------------------------------------------
# Epoch : 27, Train Acc : 88.487
# Epoch : 27, Test Acc : 78.475
# --------------------------------------------------------------
# Epoch : 28, Train Acc : 88.650
# Epoch : 28, Test Acc : 81.475
# --------------------------------------------------------------
# Epoch : 29, Train Acc : 88.925
# Epoch : 29, Test Acc : 86.425
# --------------------------------------------------------------
# Epoch : 30, Train Acc : 89.319
# Epoch : 30, Test Acc : 88.425
# --------------------------------------------------------------
# Epoch : 31, Train Acc : 89.575
# Epoch : 31, Test Acc : 82.750
# --------------------------------------------------------------
# Epoch : 32, Train Acc : 89.700
# Epoch : 32, Test Acc : 84.275
# --------------------------------------------------------------
# Epoch : 33, Train Acc : 89.394
# Epoch : 33, Test Acc : 83.550
# --------------------------------------------------------------
# Epoch : 34, Train Acc : 89.944
# Epoch : 34, Test Acc : 88.850
# --------------------------------------------------------------
# Epoch : 35, Train Acc : 90.494
# Epoch : 35, Test Acc : 88.825
# --------------------------------------------------------------
# Epoch : 36, Train Acc : 90.681
# Epoch : 36, Test Acc : 86.800
# --------------------------------------------------------------
# Epoch : 37, Train Acc : 90.812
# Epoch : 37, Test Acc : 82.450
# --------------------------------------------------------------
# Epoch : 38, Train Acc : 90.431
# Epoch : 38, Test Acc : 78.125
# --------------------------------------------------------------
# Epoch : 39, Train Acc : 90.944
# Epoch : 39, Test Acc : 84.575
# --------------------------------------------------------------
# Epoch : 40, Train Acc : 91.681
# Epoch : 40, Test Acc : 89.950
# --------------------------------------------------------------
# Epoch : 41, Train Acc : 91.500
# Epoch : 41, Test Acc : 86.800
# --------------------------------------------------------------
# Epoch : 42, Train Acc : 91.600
# Epoch : 42, Test Acc : 90.075
# --------------------------------------------------------------
# Epoch : 43, Train Acc : 91.925
# Epoch : 43, Test Acc : 88.575
# --------------------------------------------------------------
# Epoch : 44, Train Acc : 91.769
# Epoch : 44, Test Acc : 90.700
# --------------------------------------------------------------
# Epoch : 45, Train Acc : 92.156
# Epoch : 45, Test Acc : 88.975
# --------------------------------------------------------------
# Epoch : 46, Train Acc : 92.062
# Epoch : 46, Test Acc : 91.050
# --------------------------------------------------------------
# Epoch : 47, Train Acc : 92.400
# Epoch : 47, Test Acc : 88.000
# --------------------------------------------------------------
# Epoch : 48, Train Acc : 92.862
# Epoch : 48, Test Acc : 90.150
# --------------------------------------------------------------
# Epoch : 49, Train Acc : 92.562
# Epoch : 49, Test Acc : 88.650
# --------------------------------------------------------------
# Epoch : 50, Train Acc : 93.200
# Epoch : 50, Test Acc : 91.725
# --------------------------------------------------------------
# Epoch : 51, Train Acc : 93.081
# Epoch : 51, Test Acc : 91.200
# --------------------------------------------------------------
# Epoch : 52, Train Acc : 93.094
# Epoch : 52, Test Acc : 88.275
# --------------------------------------------------------------
# Epoch : 53, Train Acc : 93.394
# Epoch : 53, Test Acc : 90.350
# --------------------------------------------------------------
# Epoch : 54, Train Acc : 93.612
# Epoch : 54, Test Acc : 84.875
# --------------------------------------------------------------
# Epoch : 55, Train Acc : 93.600
# Epoch : 55, Test Acc : 90.300
# --------------------------------------------------------------
# Epoch : 56, Train Acc : 93.763
# Epoch : 56, Test Acc : 82.150
# --------------------------------------------------------------
# Epoch : 57, Train Acc : 93.575
# Epoch : 57, Test Acc : 90.950
# --------------------------------------------------------------
# Epoch : 58, Train Acc : 94.006
# Epoch : 58, Test Acc : 89.400
# --------------------------------------------------------------
# Epoch : 59, Train Acc : 94.056
# Epoch : 59, Test Acc : 90.575
# --------------------------------------------------------------
# Epoch : 60, Train Acc : 94.256
# Epoch : 60, Test Acc : 89.900
# --------------------------------------------------------------
# Epoch : 61, Train Acc : 94.213
# Epoch : 61, Test Acc : 90.450
# --------------------------------------------------------------
# Epoch : 62, Train Acc : 94.694
# Epoch : 62, Test Acc : 89.625
# --------------------------------------------------------------
# Epoch : 63, Train Acc : 94.513
# Epoch : 63, Test Acc : 91.425
# --------------------------------------------------------------
# Epoch : 64, Train Acc : 94.694
# Epoch : 64, Test Acc : 92.575
# --------------------------------------------------------------
# Epoch : 65, Train Acc : 94.763
# Epoch : 65, Test Acc : 89.725
# --------------------------------------------------------------
# Epoch : 66, Train Acc : 95.013
# Epoch : 66, Test Acc : 91.475
# --------------------------------------------------------------
# Epoch : 67, Train Acc : 95.263
# Epoch : 67, Test Acc : 91.450
# --------------------------------------------------------------
# Epoch : 68, Train Acc : 95.312
# Epoch : 68, Test Acc : 91.725
# --------------------------------------------------------------
# Epoch : 69, Train Acc : 95.769
# Epoch : 69, Test Acc : 92.475
# --------------------------------------------------------------
# Epoch : 70, Train Acc : 95.537
# Epoch : 70, Test Acc : 89.475
# --------------------------------------------------------------
# Epoch : 71, Train Acc : 95.469
# Epoch : 71, Test Acc : 92.050
# --------------------------------------------------------------
# Epoch : 72, Train Acc : 95.862
# Epoch : 72, Test Acc : 92.250
# --------------------------------------------------------------
# Epoch : 73, Train Acc : 95.694
# Epoch : 73, Test Acc : 90.650
# --------------------------------------------------------------
# Epoch : 74, Train Acc : 95.775
# Epoch : 74, Test Acc : 91.225
# --------------------------------------------------------------
# Epoch : 75, Train Acc : 95.856
# Epoch : 75, Test Acc : 93.025
# --------------------------------------------------------------
# Epoch : 76, Train Acc : 96.175
# Epoch : 76, Test Acc : 91.575
# --------------------------------------------------------------
# Epoch : 77, Train Acc : 96.344
# Epoch : 77, Test Acc : 91.175
# --------------------------------------------------------------
# Epoch : 78, Train Acc : 96.537
# Epoch : 78, Test Acc : 93.025
# --------------------------------------------------------------
# Epoch : 79, Train Acc : 96.519
# Epoch : 79, Test Acc : 92.600
# --------------------------------------------------------------
# Epoch : 80, Train Acc : 96.425
# Epoch : 80, Test Acc : 91.950
# --------------------------------------------------------------
# Epoch : 81, Train Acc : 96.600
# Epoch : 81, Test Acc : 91.550
# --------------------------------------------------------------
# Epoch : 82, Train Acc : 96.562
# Epoch : 82, Test Acc : 91.775
# --------------------------------------------------------------
# Epoch : 83, Train Acc : 96.862
# Epoch : 83, Test Acc : 91.075
# --------------------------------------------------------------
# Epoch : 84, Train Acc : 97.019
# Epoch : 84, Test Acc : 91.075
# --------------------------------------------------------------
# Epoch : 85, Train Acc : 96.862
# Epoch : 85, Test Acc : 92.850
# --------------------------------------------------------------
# Epoch : 86, Train Acc : 97.044
# Epoch : 86, Test Acc : 92.525
# --------------------------------------------------------------
# Epoch : 87, Train Acc : 97.125
# Epoch : 87, Test Acc : 92.975
# --------------------------------------------------------------
# Epoch : 88, Train Acc : 97.306
# Epoch : 88, Test Acc : 93.100
# --------------------------------------------------------------
# Epoch : 89, Train Acc : 97.106
# Epoch : 89, Test Acc : 90.600
# --------------------------------------------------------------
# Epoch : 90, Train Acc : 97.325
# Epoch : 90, Test Acc : 93.300
# --------------------------------------------------------------
# Epoch : 91, Train Acc : 97.825
# Epoch : 91, Test Acc : 90.925
# --------------------------------------------------------------
# Epoch : 92, Train Acc : 97.381
# Epoch : 92, Test Acc : 84.575
# --------------------------------------------------------------
# Epoch : 93, Train Acc : 97.606
# Epoch : 93, Test Acc : 92.575
# --------------------------------------------------------------
# Epoch : 94, Train Acc : 97.688
# Epoch : 94, Test Acc : 93.000
# --------------------------------------------------------------
# Epoch : 95, Train Acc : 97.775
# Epoch : 95, Test Acc : 92.100
# --------------------------------------------------------------
# Epoch : 96, Train Acc : 97.913
# Epoch : 96, Test Acc : 93.525
# --------------------------------------------------------------
# Epoch : 97, Train Acc : 98.000
# Epoch : 97, Test Acc : 92.450
# --------------------------------------------------------------
# Epoch : 98, Train Acc : 97.988
# Epoch : 98, Test Acc : 91.750
# --------------------------------------------------------------
# Epoch : 99, Train Acc : 97.881
# Epoch : 99, Test Acc : 92.825
# --------------------------------------------------------------

# %% [markdown]
# ## VGG11 with image size of 64

# %%
model = vgg.VGG('VGG11')
if cuda_available:
    model.cuda()
    model = torch.nn.DataParallel(model, device_ids=range(torch.cuda.device_count()))
    cudnn.benchmark = True

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=LR_0, momentum=0.9, weight_decay=5e-4)

train_acc_list, valid_acc_list = train_model(model,train_data_loader,valid_data_loader,criterion,optimizer,50, path = './checkpoint/vgg11')
# Out:
# Epoch : 0, Train Acc : 51.106
# Epoch : 0, Valid Acc : 51.400
# --------------------------------------------------------------
# Saving..
# Epoch : 1, Train Acc : 51.531
# Epoch : 1, Valid Acc : 48.600
# --------------------------------------------------------------
# Epoch : 2, Train Acc : 52.100
# Epoch : 2, Valid Acc : 53.725
# --------------------------------------------------------------
# Saving..
# Epoch : 3, Train Acc : 54.219
# Epoch : 3, Valid Acc : 57.475
# --------------------------------------------------------------
# Saving..
# Epoch : 4, Train Acc : 60.088
# Epoch : 4, Valid Acc : 63.625
# --------------------------------------------------------------
# Saving..
# Epoch : 5, Train Acc : 67.463
# Epoch : 5, Valid Acc : 65.425
# --------------------------------------------------------------
# Saving..
# Epoch : 6, Train Acc : 71.775
# Epoch : 6, Valid Acc : 75.350
# --------------------------------------------------------------
# Saving..
# Epoch : 7, Train Acc : 74.737
# Epoch : 7, Valid Acc : 74.575
# --------------------------------------------------------------
# Epoch : 8, Train Acc : 78.350
# Epoch : 8, Valid Acc : 80.000
# --------------------------------------------------------------
# Saving..
# Epoch : 9, Train Acc : 81.831
# Epoch : 9, Valid Acc : 81.075
# --------------------------------------------------------------
# Saving..
# Epoch : 10, Train Acc : 83.275
# Epoch : 10, Valid Acc : 80.300
# --------------------------------------------------------------
# Epoch : 11, Train Acc : 84.919
# Epoch : 11, Valid Acc : 79.075
# --------------------------------------------------------------
# Epoch : 12, Train Acc : 85.969
# Epoch : 12, Valid Acc : 87.175
# --------------------------------------------------------------
# Saving..
# Epoch : 13, Train Acc : 87.025
# Epoch : 13, Valid Acc : 83.550
# --------------------------------------------------------------
# Epoch : 14, Train Acc : 87.475
# Epoch : 14, Valid Acc : 86.200
# --------------------------------------------------------------
# Epoch : 15, Train Acc : 88.219
# Epoch : 15, Valid Acc : 77.300
# --------------------------------------------------------------
# Epoch : 16, Train Acc : 88.812
# Epoch : 16, Valid Acc : 80.200
# --------------------------------------------------------------
# Epoch : 17, Train Acc : 89.350
# Epoch : 17, Valid Acc : 87.575
# --------------------------------------------------------------
# Saving..
# Epoch : 18, Train Acc : 89.419
# Epoch : 18, Valid Acc : 88.275
# --------------------------------------------------------------
# Saving..
# Epoch : 19, Train Acc : 89.944
# Epoch : 19, Valid Acc : 84.175
# --------------------------------------------------------------
# Epoch : 20, Train Acc : 90.494
# Epoch : 20, Valid Acc : 88.250
# --------------------------------------------------------------
# Epoch : 21, Train Acc : 91.069
# Epoch : 21, Valid Acc : 88.250
# --------------------------------------------------------------
# Epoch : 22, Train Acc : 91.725
# Epoch : 22, Valid Acc : 87.175
# --------------------------------------------------------------
# Epoch : 23, Train Acc : 91.938
# Epoch : 23, Valid Acc : 89.100
# --------------------------------------------------------------
# Saving..
# Epoch : 24, Train Acc : 92.513
# Epoch : 24, Valid Acc : 88.550
# --------------------------------------------------------------
# Epoch : 25, Train Acc : 93.200
# Epoch : 25, Valid Acc : 83.950
# --------------------------------------------------------------
# Epoch : 26, Train Acc : 93.381
# Epoch : 26, Valid Acc : 88.150
# --------------------------------------------------------------
# Epoch : 27, Train Acc : 93.375
# Epoch : 27, Valid Acc : 83.375
# --------------------------------------------------------------
# Epoch : 28, Train Acc : 93.950
# Epoch : 28, Valid Acc : 89.750
# --------------------------------------------------------------
# Saving..
# Epoch : 29, Train Acc : 94.119
# Epoch : 29, Valid Acc : 88.100
# --------------------------------------------------------------
# Epoch : 30, Train Acc : 94.663
# Epoch : 30, Valid Acc : 87.725
# --------------------------------------------------------------
# Epoch : 31, Train Acc : 94.981
# Epoch : 31, Valid Acc : 88.875
# --------------------------------------------------------------
# Epoch : 32, Train Acc : 95.244
# Epoch : 32, Valid Acc : 90.050
# --------------------------------------------------------------
# Saving..
# Epoch : 33, Train Acc : 95.731
# Epoch : 33, Valid Acc : 90.300
# --------------------------------------------------------------
# Saving..
# Epoch : 34, Train Acc : 95.750
# Epoch : 34, Valid Acc : 89.925
# --------------------------------------------------------------
# Epoch : 35, Train Acc : 96.069
# Epoch : 35, Valid Acc : 90.475
# --------------------------------------------------------------
# Saving..
# Epoch : 36, Train Acc : 96.656
# Epoch : 36, Valid Acc : 88.950
# --------------------------------------------------------------
# Epoch : 37, Train Acc : 96.475
# Epoch : 37, Valid Acc : 90.075
# --------------------------------------------------------------
# Epoch : 38, Train Acc : 96.850
# Epoch : 38, Valid Acc : 87.825
# --------------------------------------------------------------
# Epoch : 39, Train Acc : 97.062
# Epoch : 39, Valid Acc : 89.850
# --------------------------------------------------------------
# Epoch : 40, Train Acc : 97.438
# Epoch : 40, Valid Acc : 90.775
# --------------------------------------------------------------
# Saving..
# Epoch : 41, Train Acc : 97.456
# Epoch : 41, Valid Acc : 90.250
# --------------------------------------------------------------
# Epoch : 42, Train Acc : 97.700
# Epoch : 42, Valid Acc : 91.825
# --------------------------------------------------------------
# Saving..
# Epoch : 43, Train Acc : 97.806
# Epoch : 43, Valid Acc : 91.075
# --------------------------------------------------------------
# Epoch : 44, Train Acc : 98.094
# Epoch : 44, Valid Acc : 88.650
# --------------------------------------------------------------
# Epoch : 45, Train Acc : 98.062
# Epoch : 45, Valid Acc : 91.225
# --------------------------------------------------------------
# Epoch : 46, Train Acc : 98.487
# Epoch : 46, Valid Acc : 90.650
# --------------------------------------------------------------
# Epoch : 47, Train Acc : 98.619
# Epoch : 47, Valid Acc : 90.575
# --------------------------------------------------------------
# Epoch : 48, Train Acc : 98.494
# Epoch : 48, Valid Acc : 83.425
# --------------------------------------------------------------
# Epoch : 49, Train Acc : 98.694
# Epoch : 49, Valid Acc : 92.050
# --------------------------------------------------------------
# Saving..

# %% [markdown]
# ## Use pretrained models

# %%
# Training
def train(train_loader, model, criterion, optimizer, epoch):
    model.train()
    train_loss = 0
    correct = 0
    total = 0
    for batch_idx, (inputs, targets) in enumerate(train_loader):
        if cuda_available:
            inputs, targets = inputs.cuda(), targets.cuda()
        optimizer.zero_grad()
        inputs, targets = Variable(inputs), Variable(targets)
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()

        train_loss += loss.data[0]
        _, predicted = torch.max(outputs.data, 1)
        total += targets.size(0)
        correct += predicted.eq(targets.data).cpu().sum()
        train_acc = correct/total

#        utils.progress_bar(batch_idx, len(train_data_loader), 'Loss: %.3f | Acc: %.3f%% (%d/%d)'
#            % (train_loss/(batch_idx+1), 100.*correct/total, correct, total))
    
    print('Epoch : %d, Train Acc : %.3f' % (epoch, 100.*train_acc))
#            print('--------------------------------------------------------------')
    return train_acc
    
# evaluate
def evaluate(valid_loader, model, criterion, epoch, path = './checkpoint/vgg16'):
    global best_acc
    model.eval()
    test_loss = 0
    correct = 0
    total = 0
    for batch_idx, (inputs, targets) in enumerate(valid_loader):
        if cuda_available:
            inputs, targets = inputs.cuda(), targets.cuda()
        inputs, targets = Variable(inputs, volatile=True), Variable(targets)
        outputs = model(inputs)
        loss = criterion(outputs, targets)

        test_loss += loss.data[0]
        _, predicted = torch.max(outputs.data, 1)
        total += targets.size(0)
        correct += predicted.eq(targets.data).cpu().sum()
        test_acc = correct/total

    print('Epoch : %d, Valid Acc : %.3f' % (epoch, 100.*test_acc))
    print('--------------------------------------------------------------')

    # Save checkpoint.
    acc = 100.*correct/total
    if acc > best_acc:
        print('Saving..')
        state = {
            'net': model.module if cuda_available else model,
            'acc': acc,
            'epoch': epoch,
        }
        if not os.path.isdir('checkpoint'):
            os.mkdir('checkpoint')
        torch.save(state, path)
        best_acc = acc
        
    return test_acc

# test
def test(test_loader, model):
    model.eval()
    test_loss = 0
    correct = 0
    total = 0
    for batch_idx, (inputs, targets) in enumerate(test_loader):
        if cuda_available:
            inputs, targets = inputs.cuda(), targets.cuda()
        inputs, targets = Variable(inputs, volatile=True), Variable(targets)
        outputs = model(inputs)
        loss = criterion(outputs, targets)

        test_loss += loss.data[0]
        _, predicted = torch.max(outputs.data, 1)
        total += targets.size(0)
        correct += predicted.eq(targets.data).cpu().sum()
        test_acc = correct/total

    print('Test Acc : %.3f' % ( 100.*test_acc))


def adjust_lr(optimizer, epoch, total_epochs):
    lr = LR_0 * (0.1 ** (epoch / float(total_epochs)))
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

#model = train_model(dloaders, net, criterion, optimizer, exp_lr_scheduler, num_epochs=2)
#print('Training time: {:10f} minutes'.format((time.time()-start_time)/60))

def train_model(model, train_loader, valid_loader, criterion, optimizer, num_epochs=25, path = './checkpoint/vgg16') :
    train_acc_list=[]
    valid_acc_list=[]
    for epoch in range(0, num_epochs):
        train_acc_list.append(train(train_loader, model, criterion, optimizer, epoch))
        adjust_lr(optimizer,epoch,num_epochs)
        valid_acc_list.append(evaluate(valid_loader, model, criterion, epoch, path))
    return train_acc_list, valid_acc_list
    
class FineTuneModel(nn.Module):
    def __init__(self, original_model, arch, num_classes):
        super(FineTuneModel, self).__init__()

        if arch.startswith('alexnet') :
            self.features = original_model.features
            self.classifier = nn.Sequential(
                nn.Dropout(),
                nn.Linear(256 * 6 * 6, 4096),
                nn.ReLU(inplace=True),
                nn.Dropout(),
                nn.Linear(4096, 4096),
                nn.ReLU(inplace=True),
                nn.Linear(4096, num_classes),
            )
            self.modelName = 'alexnet'
        elif arch.startswith('resnet') :
            # Everything except the last linear layer
            self.features = nn.Sequential(*list(original_model.children())[:-1])
            self.classifier = nn.Sequential(
                nn.Linear(512, num_classes)
            )
            self.modelName = 'resnet'
        elif arch.startswith('vgg16'):
            self.features = original_model.features
            self.classifier = nn.Sequential(
                nn.Dropout(),
                nn.Linear(25088, 4096),
                nn.ReLU(inplace=True),
                nn.Dropout(),
                nn.Linear(4096, 4096),
                nn.ReLU(inplace=True),
                nn.Linear(4096, num_classes),
            )
            self.modelName = 'vgg16'
        else :
            raise("Finetuning not supported on this architecture yet")

        # Freeze those weights
        for p in self.features.parameters():
            p.requires_grad = False
        for p in self.classifier.parameters():
            p.requires_grad = False
        for p in self.classifier[6].parameters():
            p.requires_grad = True


    def forward(self, x):
        f = self.features(x)
        if self.modelName == 'alexnet' :
            f = f.view(f.size(0), 256 * 6 * 6)
        elif self.modelName == 'vgg16':
            f = f.view(f.size(0), -1)
        elif self.modelName == 'resnet' :
            f = f.view(f.size(0), -1)
        y = self.classifier(f)
        return y

# %%
print(os.getcwd())


'''
# Set hyper parameters.
'''
IMAGES_ROOT = 'datasets/PetImages'
MY_TEST_ROOT = 'datasets/my_test'
MODEL_SAVE_PATH='output'
MODEL_SAVE_INTERVAL = 5

# hyper parameters of Deep learning
IMAGE_RESIZE=224
TRAIN_SIZE = 16000
VALID_SIZE = 4000
TEST_SIZE = 4990
EPOCH_NUM = 100
BATCH_SIZE_TRAIN=25
BATCH_SIZE_VALID=50
BATCH_SIZE_TEST = 16
LR_0=0.1
MOMENTUM=0.9
WEIGHT_DECAY=5e-4
resume = True
best_acc = 0

cuda_available = torch.cuda.is_available()
#%%
'''
# Load the dog_vs_cat data
'''

indices = list(range(TRAIN_SIZE+VALID_SIZE+TEST_SIZE))
np.random.seed(123)
np.random.shuffle(indices)

train_idx, valid_idx, test_idx = indices[:TRAIN_SIZE], indices[TRAIN_SIZE:(TRAIN_SIZE+VALID_SIZE)], indices[(TRAIN_SIZE+VALID_SIZE):]

train_sampler = sampler.SubsetRandomSampler(train_idx)
valid_sampler = sampler.SubsetRandomSampler(valid_idx)
test_sampler = sampler.SubsetRandomSampler(test_idx)

normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
data_transform = transforms.Compose([
    transforms.Resize((IMAGE_RESIZE, IMAGE_RESIZE), interpolation=Image.BILINEAR),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[
                            0.229, 0.224, 0.225])
])

dataset = datasets.ImageFolder(root=IMAGES_ROOT, transform=data_transform)

train_data_loader = torch.utils.data.DataLoader(
    dataset, batch_size=BATCH_SIZE_TRAIN, sampler=train_sampler, num_workers=10)

valid_data_loader = torch.utils.data.DataLoader(
    dataset, batch_size=BATCH_SIZE_VALID,  sampler=valid_sampler, num_workers=10)

test_data_loader = torch.utils.data.DataLoader(
    dataset, batch_size=BATCH_SIZE_TEST,  sampler=test_sampler, num_workers=10)

my_testset = datasets.ImageFolder(root=MY_TEST_ROOT, transform=data_transform)

my_data_loader = torch.utils.data.DataLoader(
    my_testset, batch_size=BATCH_SIZE_VALID, shuffle=False, num_workers=10)

print('Loaded images(train and valid), total',len(train_sampler)+len(valid_sampler))
print('Loaded test images, total',len(test_sampler))
print('Image size: ', dataset[0][0].size())
# Out:
# C:\Users\lingyu.yue\Documents\Xiao_Fan\20180304
# Loaded images(train and valid), total 20000
# Loaded test images, total 4990
# Image size:  torch.Size([3, 224, 224])

# %% [markdown]
# ### Resnet 152

# %%
net = torchvision.models.resnet152(pretrained=True)

# freeze all model parameters
for param in net.parameters():
    param.requires_grad = False

net.fc = nn.Linear(2048, 2)

if torch.cuda.is_available():
    net = net.cuda()
    net = torch.nn.DataParallel(net, device_ids=range(torch.cuda.device_count()))
    cudnn.benchmark = True

# %%
train_acc_list=[]
valid_acc_list=[]
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(net.module.fc.parameters(), lr=0.001, momentum=0.9)
train_acc_list, valid_acc_list = train_model(net,train_data_loader,valid_data_loader,criterion,optimizer,20, path = './checkpoint/resnet152')
# Out:
# Epoch : 0, Train Acc : 93.875
# Epoch : 0, Valid Acc : 96.525
# --------------------------------------------------------------
# Epoch : 1, Train Acc : 92.787
# Epoch : 1, Valid Acc : 95.650
# --------------------------------------------------------------
# Epoch : 2, Train Acc : 93.706
# Epoch : 2, Valid Acc : 96.325
# --------------------------------------------------------------
# Epoch : 3, Train Acc : 94.956
# Epoch : 3, Valid Acc : 93.925
# --------------------------------------------------------------
# Epoch : 4, Train Acc : 94.337
# Epoch : 4, Valid Acc : 96.075
# --------------------------------------------------------------
# Epoch : 5, Train Acc : 94.594
# Epoch : 5, Valid Acc : 96.575
# --------------------------------------------------------------
# Epoch : 6, Train Acc : 94.469
# Epoch : 6, Valid Acc : 95.825
# --------------------------------------------------------------
# Epoch : 7, Train Acc : 95.213
# Epoch : 7, Valid Acc : 96.825
# --------------------------------------------------------------
# Saving..
# Epoch : 8, Train Acc : 95.125
# Epoch : 8, Valid Acc : 96.025
# --------------------------------------------------------------
# Epoch : 9, Train Acc : 95.269
# Epoch : 9, Valid Acc : 93.450
# --------------------------------------------------------------
# Epoch : 10, Train Acc : 95.200
# Epoch : 10, Valid Acc : 96.625
# --------------------------------------------------------------
# Epoch : 11, Train Acc : 94.706
# Epoch : 11, Valid Acc : 96.425
# --------------------------------------------------------------
# Epoch : 12, Train Acc : 94.644
# Epoch : 12, Valid Acc : 96.600
# --------------------------------------------------------------
# Epoch : 13, Train Acc : 95.600
# Epoch : 13, Valid Acc : 96.950
# --------------------------------------------------------------
# Saving..
# Epoch : 14, Train Acc : 95.469
# Epoch : 14, Valid Acc : 97.325
# --------------------------------------------------------------
# Saving..
# Epoch : 15, Train Acc : 95.175
# Epoch : 15, Valid Acc : 96.875
# --------------------------------------------------------------
# Epoch : 16, Train Acc : 95.912
# Epoch : 16, Valid Acc : 96.775
# --------------------------------------------------------------
# Epoch : 17, Train Acc : 95.369
# Epoch : 17, Valid Acc : 96.525
# --------------------------------------------------------------
# Epoch : 18, Train Acc : 95.769
# Epoch : 18, Valid Acc : 96.550
# --------------------------------------------------------------
# Epoch : 19, Train Acc : 95.450
# Epoch : 19, Valid Acc : 96.975
# --------------------------------------------------------------
# ([0.93875,
#   0.927875,
#   0.9370625,
#   0.9495625,
#   0.943375,
#   0.9459375,
#   0.9446875,
#   0.952125,
#   0.95125,
#   0.9526875,
#   0.952,
#   0.9470625,
#   0.9464375,
#   0.956,
#   0.9546875,
#   0.95175,
#   0.959125,
#   0.9536875,
#   0.9576875,
#   0.9545],
#  [0.96525,
#   0.9565,
#   0.96325,
#   0.93925,
#   0.96075,
#   0.96575,
#   0.95825,
#   0.96825,
#   0.96025,
#   0.9345,
#   0.96625,
#   0.96425,
#   0.966,
#   0.9695,
#   0.97325,
#   0.96875,
#   0.96775,
#   0.96525,
#   0.9655,
#   0.96975])

# %%
plt.plot(range(0,20),train_acc_list,label='Training')
plt.plot(range(0,20),valid_acc_list,label='Validation')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig('acc_resnet152.pdf')
plt.show()

# %%
# Load checkpoint.
print('==> Resuming from checkpoint..')
assert os.path.isdir('checkpoint'), 'Error: no checkpoint directory found!'
checkpoint = torch.load('./checkpoint/resnet152')
net = checkpoint['net']
best_acc = checkpoint['acc']
start_epoch = checkpoint['epoch']
print ('Best validation acc : %.3f' % (best_acc))
test(test_data_loader, net)
# Out:
# ==> Resuming from checkpoint..
# Best validation acc : 97.325
# Test Acc : 96.273

# %%
# resnet152
net = torchvision.models.resnet152(pretrained=True)

# freeze all model parameters
for param in net.parameters():
    param.requires_grad = False

net.fc = nn.Linear(2048, 2)

if torch.cuda.is_available():
    net = net.cuda()
    net = torch.nn.DataParallel(net, device_ids=range(torch.cuda.device_count()))
    cudnn.benchmark = True
    
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(net.module.fc.parameters(), lr=0.001, momentum=0.9,weight_decay = WEIGHT_DECAY)
train_acc_list, valid_acc_list = train_model(net,train_data_loader,valid_data_loader,criterion,optimizer,20, path = './checkpoint/resnet152')
# Out:
# Epoch : 0, Train Acc : 97.000
# Epoch : 0, Valid Acc : 98.625
# --------------------------------------------------------------
# Saving..
# Epoch : 1, Train Acc : 96.062
# Epoch : 1, Valid Acc : 98.350
# --------------------------------------------------------------
# Epoch : 2, Train Acc : 97.544
# Epoch : 2, Valid Acc : 97.400
# --------------------------------------------------------------
# Epoch : 3, Train Acc : 97.175
# Epoch : 3, Valid Acc : 97.175
# --------------------------------------------------------------
# Epoch : 4, Train Acc : 97.631
# Epoch : 4, Valid Acc : 92.325
# --------------------------------------------------------------
# Epoch : 5, Train Acc : 97.119
# Epoch : 5, Valid Acc : 98.375
# --------------------------------------------------------------
# Epoch : 6, Train Acc : 97.806
# Epoch : 6, Valid Acc : 98.275
# --------------------------------------------------------------
# Epoch : 7, Train Acc : 97.831
# Epoch : 7, Valid Acc : 98.375
# --------------------------------------------------------------
# Epoch : 8, Train Acc : 97.675
# Epoch : 8, Valid Acc : 98.550
# --------------------------------------------------------------
# Epoch : 9, Train Acc : 97.881
# Epoch : 9, Valid Acc : 98.550
# --------------------------------------------------------------
# Epoch : 10, Train Acc : 98.050
# Epoch : 10, Valid Acc : 98.775
# --------------------------------------------------------------
# Saving..
# Epoch : 11, Train Acc : 97.644
# Epoch : 11, Valid Acc : 98.825
# --------------------------------------------------------------
# Saving..
# Epoch : 12, Train Acc : 98.381
# Epoch : 12, Valid Acc : 99.025
# --------------------------------------------------------------
# Saving..
# Epoch : 13, Train Acc : 98.300
# Epoch : 13, Valid Acc : 98.550
# --------------------------------------------------------------
# Epoch : 14, Train Acc : 98.369
# Epoch : 14, Valid Acc : 98.850
# --------------------------------------------------------------
# Epoch : 15, Train Acc : 98.550
# Epoch : 15, Valid Acc : 98.525
# --------------------------------------------------------------
# Epoch : 16, Train Acc : 98.062
# Epoch : 16, Valid Acc : 99.000
# --------------------------------------------------------------
# Epoch : 17, Train Acc : 98.456
# Epoch : 17, Valid Acc : 98.625
# --------------------------------------------------------------
# Epoch : 18, Train Acc : 98.675
# Epoch : 18, Valid Acc : 98.775
# --------------------------------------------------------------
# Epoch : 19, Train Acc : 98.544
# Epoch : 19, Valid Acc : 98.475
# --------------------------------------------------------------

# %%
plt.plot(range(0,20),train_acc_list,label='Training')
plt.plot(range(0,20),valid_acc_list,label='Validation')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig('acc_resnet152_2.pdf')
plt.show()

# %%
# Load checkpoint.
print('==> Resuming from checkpoint..')
assert os.path.isdir('checkpoint'), 'Error: no checkpoint directory found!'
checkpoint = torch.load('./checkpoint/resnet152')
net = checkpoint['net']
best_acc = checkpoint['acc']
start_epoch = checkpoint['epoch']
print ('Best validation acc : %.3f' % (best_acc))
test(test_data_loader, net)
# Out:
# ==> Resuming from checkpoint..
# Best validation acc : 99.025
# Test Acc : 98.778

# %% [markdown]
# ## VGG16

# %%
arch = 'vgg16'
num_classes = 2
original_model = torchvision.models.vgg16_bn(pretrained=True)
model = FineTuneModel(original_model, arch, num_classes)

if arch.startswith('alexnet') or arch.startswith('vgg'):
    model.features = torch.nn.DataParallel(model.features)
    model.cuda()
else:
    model = torch.nn.DataParallel(model).cuda()
# if cuda_available:
#     model.cuda()
#     model = torch.nn.DataParallel(model, device_ids=range(torch.cuda.device_count()))
#     cudnn.benchmark = True

# %%
train_acc_list=[]
valid_acc_list=[]
optimizer = torch.optim.SGD(filter(lambda p: p.requires_grad, model.parameters()), lr=0.001, momentum=0.9)
train_acc_list, valid_acc_list = train_model(model,train_data_loader,valid_data_loader,criterion,optimizer,20, path = './checkpoint/vgg16')
# Out:
# Epoch : 0, Train Acc : 79.831
# Epoch : 0, Valid Acc : 91.625
# --------------------------------------------------------------
# Saving..
# C:\Users\lingyu.yue\Anaconda3\lib\site-packages\torch\serialization.py:158: UserWarning: Couldn't retrieve source code for container of type FineTuneModel. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# Epoch : 1, Train Acc : 90.012
# Epoch : 1, Valid Acc : 92.200
# --------------------------------------------------------------
# Saving..
# Epoch : 2, Train Acc : 92.381
# Epoch : 2, Valid Acc : 95.150
# --------------------------------------------------------------
# Saving..
# Epoch : 3, Train Acc : 92.775
# Epoch : 3, Valid Acc : 92.050
# --------------------------------------------------------------
# Epoch : 4, Train Acc : 93.575
# Epoch : 4, Valid Acc : 87.775
# --------------------------------------------------------------
# Epoch : 5, Train Acc : 93.362
# Epoch : 5, Valid Acc : 91.925
# --------------------------------------------------------------
# Epoch : 6, Train Acc : 93.625
# Epoch : 6, Valid Acc : 93.425
# --------------------------------------------------------------
# Epoch : 7, Train Acc : 93.950
# Epoch : 7, Valid Acc : 91.950
# --------------------------------------------------------------
# Epoch : 8, Train Acc : 94.256
# Epoch : 8, Valid Acc : 91.500
# --------------------------------------------------------------
# Epoch : 9, Train Acc : 94.050
# Epoch : 9, Valid Acc : 91.450
# --------------------------------------------------------------
# Epoch : 10, Train Acc : 94.156
# Epoch : 10, Valid Acc : 92.650
# --------------------------------------------------------------
# Epoch : 11, Train Acc : 94.306
# Epoch : 11, Valid Acc : 90.525
# --------------------------------------------------------------
# Epoch : 12, Train Acc : 94.106
# Epoch : 12, Valid Acc : 92.325
# --------------------------------------------------------------
# Epoch : 13, Train Acc : 94.669
# Epoch : 13, Valid Acc : 90.350
# --------------------------------------------------------------
# Epoch : 14, Train Acc : 94.700
# Epoch : 14, Valid Acc : 92.475
# --------------------------------------------------------------
# Epoch : 15, Train Acc : 94.675
# Epoch : 15, Valid Acc : 91.725
# --------------------------------------------------------------
# Epoch : 16, Train Acc : 94.600
# Epoch : 16, Valid Acc : 92.975
# --------------------------------------------------------------
# Epoch : 17, Train Acc : 94.406
# Epoch : 17, Valid Acc : 90.450
# --------------------------------------------------------------
# Epoch : 18, Train Acc : 94.606
# Epoch : 18, Valid Acc : 92.325
# --------------------------------------------------------------
# Epoch : 19, Train Acc : 95.025
# Epoch : 19, Valid Acc : 92.925
# --------------------------------------------------------------

# %%
# Load checkpoint.
print('==> Resuming from checkpoint..')
assert os.path.isdir('checkpoint'), 'Error: no checkpoint directory found!'
checkpoint = torch.load('./checkpoint/vgg16')
net = checkpoint['net']
best_acc = checkpoint['acc']
start_epoch = checkpoint['epoch']
print ('Best validation acc : %.3f' % (best_acc))
test(test_data_loader, net)
# Out:
# ==> Resuming from checkpoint..
# Best validation acc : 95.150
# Test Acc : 95.170

# %%
train_acc_list=[]
valid_acc_list=[]
optimizer = torch.optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=0.005)
train_acc_list, valid_acc_list = train_model(model,train_data_loader,valid_data_loader,criterion,optimizer,20)
# Out:
# Epoch : 0, Train Acc : 79.550
# Epoch : 0, Valid Acc : 90.900
# --------------------------------------------------------------
# Epoch : 1, Train Acc : 76.694
# Epoch : 1, Valid Acc : 87.925
# --------------------------------------------------------------
# Epoch : 2, Train Acc : 79.575
# Epoch : 2, Valid Acc : 87.675
# --------------------------------------------------------------
# Epoch : 3, Train Acc : 81.612
# Epoch : 3, Valid Acc : 90.150
# --------------------------------------------------------------
# Epoch : 4, Train Acc : 81.863
# Epoch : 4, Valid Acc : 89.000
# --------------------------------------------------------------
# Epoch : 5, Train Acc : 81.594
# Epoch : 5, Valid Acc : 88.100
# --------------------------------------------------------------
# Epoch : 6, Train Acc : 82.069
# Epoch : 6, Valid Acc : 90.975
# --------------------------------------------------------------
# Epoch : 7, Train Acc : 82.181
# Epoch : 7, Valid Acc : 87.575
# --------------------------------------------------------------
# Epoch : 8, Train Acc : 82.100
# Epoch : 8, Valid Acc : 84.625
# --------------------------------------------------------------
# Epoch : 9, Train Acc : 82.975
# Epoch : 9, Valid Acc : 90.150
# --------------------------------------------------------------
# Epoch : 10, Train Acc : 82.894
# Epoch : 10, Valid Acc : 79.425
# --------------------------------------------------------------
# Epoch : 11, Train Acc : 82.962
# Epoch : 11, Valid Acc : 85.250
# --------------------------------------------------------------
# Epoch : 12, Train Acc : 83.788
# Epoch : 12, Valid Acc : 89.125
# --------------------------------------------------------------
# Epoch : 13, Train Acc : 83.362
# Epoch : 13, Valid Acc : 80.450
# --------------------------------------------------------------
# Epoch : 14, Train Acc : 83.600
# Epoch : 14, Valid Acc : 84.825
# --------------------------------------------------------------
# Epoch : 15, Train Acc : 83.962
# Epoch : 15, Valid Acc : 82.175
# --------------------------------------------------------------
# Epoch : 16, Train Acc : 84.631
# Epoch : 16, Valid Acc : 87.600
# --------------------------------------------------------------
# Epoch : 17, Train Acc : 84.069
# Epoch : 17, Valid Acc : 86.525
# --------------------------------------------------------------
# Epoch : 18, Train Acc : 84.381
# Epoch : 18, Valid Acc : 84.075
# --------------------------------------------------------------
# Epoch : 19, Train Acc : 83.737
# Epoch : 19, Valid Acc : 83.375
# --------------------------------------------------------------

# %%
optimizer = torch.optim.SGD(filter(lambda p: p.requires_grad, model.parameters()), lr=0.005, momentum=0.9, weight_decay=WEIGHT_DECAY)
train_acc_list, valid_acc_list = train_model(model,train_data_loader,valid_data_loader,criterion,optimizer,10)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-32-4b72cb3e3680> in <module>()
#       1 optimizer = torch.optim.SGD(filter(lambda p: p.requires_grad, model.parameters()), lr=0.005, momentum=0.9, weight_decay=WEIGHT_DECAY)
# ----> 2 train_acc_list, valid_acc_list = train_model(model,train_data_loader,valid_data_loader,criterion,optimizer,10)
#
# <ipython-input-29-c2ff317a1e75> in train_model(model, train_loader, valid_loader, criterion, optimizer, num_epochs, path)
#     101     valid_acc_list=[]
#     102     for epoch in range(0, num_epochs):
# --> 103         train_acc_list.append(train(train_loader, model, criterion, optimizer, epoch))
#     104         adjust_lr(optimizer,epoch,num_epochs)
#     105         valid_acc_list.append(evaluate(valid_loader, model, criterion, epoch, path))
#
# <ipython-input-29-c2ff317a1e75> in train(train_loader, model, criterion, optimizer, epoch)
#      10         optimizer.zero_grad()
#      11         inputs, targets = Variable(inputs), Variable(targets)
# ---> 12         outputs = model(inputs)
#      13         loss = criterion(outputs, targets)
#      14         loss.backward()
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     323         for hook in self._forward_pre_hooks.values():
#     324             hook(self, input)
# --> 325         result = self.forward(*input, **kwargs)
#     326         for hook in self._forward_hooks.values():
#     327             hook_result = hook(self, input, result)
#
# <ipython-input-29-c2ff317a1e75> in forward(self, x)
#     154
#     155     def forward(self, x):
# --> 156         f = self.features(x)
#     157         if self.modelName == 'alexnet' :
#     158             f = f.view(f.size(0), 256 * 6 * 6)
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     323         for hook in self._forward_pre_hooks.values():
#     324             hook(self, input)
# --> 325         result = self.forward(*input, **kwargs)
#     326         for hook in self._forward_hooks.values():
#     327             hook_result = hook(self, input, result)
#
# ~\Anaconda3\lib\site-packages\torch\nn\parallel\data_parallel.py in forward(self, *inputs, **kwargs)
#      64         inputs, kwargs = self.scatter(inputs, kwargs, self.device_ids)
#      65         if len(self.device_ids) == 1:
# ---> 66             return self.module(*inputs[0], **kwargs[0])
#      67         replicas = self.replicate(self.module, self.device_ids[:len(inputs)])
#      68         outputs = self.parallel_apply(replicas, inputs, kwargs)
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     323         for hook in self._forward_pre_hooks.values():
#     324             hook(self, input)
# --> 325         result = self.forward(*input, **kwargs)
#     326         for hook in self._forward_hooks.values():
#     327             hook_result = hook(self, input, result)
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\container.py in forward(self, input)
#      65     def forward(self, input):
#      66         for module in self._modules.values():
# ---> 67             input = module(input)
#      68         return input
#      69
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     323         for hook in self._forward_pre_hooks.values():
#     324             hook(self, input)
# --> 325         result = self.forward(*input, **kwargs)
#     326         for hook in self._forward_hooks.values():
#     327             hook_result = hook(self, input, result)
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\conv.py in forward(self, input)
#     275     def forward(self, input):
#     276         return F.conv2d(input, self.weight, self.bias, self.stride,
# --> 277                         self.padding, self.dilation, self.groups)
#     278
#     279
#
# ~\Anaconda3\lib\site-packages\torch\nn\functional.py in conv2d(input, weight, bias, stride, padding, dilation, groups)
#      88                 _pair(0), groups, torch.backends.cudnn.benchmark,
#      89                 torch.backends.cudnn.deterministic, torch.backends.cudnn.enabled)
# ---> 90     return f(input, weight, bias)
#      91
#      92
#
# RuntimeError: CUDA error: out of memory

# %% [markdown]
# ## VGG16 with image size = 64

# %%
class FineTuneModel2(nn.Module):
    def __init__(self, original_model, arch, num_classes):
        super(FineTuneModel2, self).__init__()

        if arch.startswith('alexnet') :
            self.features = original_model.features
            self.classifier = nn.Sequential(
                nn.Dropout(),
                nn.Linear(256 * 6 * 6, 4096),
                nn.ReLU(inplace=True),
                nn.Dropout(),
                nn.Linear(4096, 4096),
                nn.ReLU(inplace=True),
                nn.Linear(4096, num_classes),
            )
            self.modelName = 'alexnet'
        elif arch.startswith('resnet') :
            # Everything except the last linear layer
            self.features = nn.Sequential(*list(original_model.children())[:-1])
            self.classifier = nn.Sequential(
                nn.Linear(512, num_classes)
            )
            self.modelName = 'resnet'
        elif arch.startswith('vgg16'):
            self.features = original_model.features
            self.classifier = nn.Sequential(
#                nn.Dropout(),
#                nn.Linear(25088, 4096),
#                nn.ReLU(inplace=True),
#                nn.Dropout(),
#                nn.Linear(4096, 4096),
#                nn.ReLU(inplace=True),
#                nn.Linear(4096, num_classes),
                nn.Linear(2048,num_classes)
            )
            self.modelName = 'vgg16'
        else :
            raise("Finetuning not supported on this architecture yet")

        # Freeze those weights
        for p in self.features.parameters():
            p.requires_grad = False
#        for p in self.classifier.parameters():
#            p.requires_grad = False
#        for p in self.classifier[6].parameters():
#            p.requires_grad = True


    def forward(self, x):
        f = self.features(x)
        if self.modelName == 'alexnet' :
            f = f.view(f.size(0), 256 * 6 * 6)
        elif self.modelName == 'vgg16':
            f = f.view(f.size(0), -1)
        elif self.modelName == 'resnet' :
            f = f.view(f.size(0), -1)
        y = self.classifier(f)
        return y

# %%
print(os.getcwd())


'''
# Set hyper parameters.
'''
IMAGES_ROOT = 'datasets/PetImages'
MY_TEST_ROOT = 'datasets/my_test'
MODEL_SAVE_PATH='output'
MODEL_SAVE_INTERVAL = 5

# hyper parameters of Deep learning
IMAGE_RESIZE=64
TRAIN_SIZE = 16000
VALID_SIZE = 4000
TEST_SIZE = 4990
EPOCH_NUM = 100
BATCH_SIZE_TRAIN=25
BATCH_SIZE_VALID=50
BATCH_SIZE_TEST = 16
LR_0=0.1
MOMENTUM=0.9
WEIGHT_DECAY=5e-4
resume = True
best_acc = 0

cuda_available = torch.cuda.is_available()
#%%
'''
# Load the dog_vs_cat data
'''

indices = list(range(TRAIN_SIZE+VALID_SIZE+TEST_SIZE))
np.random.seed(123)
np.random.shuffle(indices)

train_idx, valid_idx, test_idx = indices[:TRAIN_SIZE], indices[TRAIN_SIZE:(TRAIN_SIZE+VALID_SIZE)], indices[(TRAIN_SIZE+VALID_SIZE):]

train_sampler = sampler.SubsetRandomSampler(train_idx)
valid_sampler = sampler.SubsetRandomSampler(valid_idx)
test_sampler = sampler.SubsetRandomSampler(test_idx)

data_transform = transforms.Compose([
    transforms.Resize((IMAGE_RESIZE, IMAGE_RESIZE), interpolation=Image.BILINEAR),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[
                            0.229, 0.224, 0.225])
])

dataset = datasets.ImageFolder(root=IMAGES_ROOT, transform=data_transform)

train_data_loader = torch.utils.data.DataLoader(
    dataset, batch_size=BATCH_SIZE_TRAIN, sampler=train_sampler, num_workers=10)

valid_data_loader = torch.utils.data.DataLoader(
    dataset, batch_size=BATCH_SIZE_VALID,  sampler=valid_sampler, num_workers=10)

test_data_loader = torch.utils.data.DataLoader(
    dataset, batch_size=BATCH_SIZE_TEST,  sampler=test_sampler, num_workers=10)

my_testset = datasets.ImageFolder(root=MY_TEST_ROOT, transform=data_transform)

my_data_loader = torch.utils.data.DataLoader(
    my_testset, batch_size=BATCH_SIZE_VALID, shuffle=False, num_workers=10)

print('Loaded images(train and valid), total',len(train_sampler)+len(valid_sampler))
print('Loaded test images, total',len(test_sampler))
print('Image size: ', dataset[0][0].size())
# Out:
# C:\Users\lingyu.yue\Documents\Xiao_Fan\20180304
# Loaded images(train and valid), total 20000
# Loaded test images, total 4990
# Image size:  torch.Size([3, 64, 64])

# %%
arch = 'vgg16'
num_classes = 2
original_model = torchvision.models.vgg16_bn(pretrained=True)
model = FineTuneModel2(original_model, arch, num_classes)

model = torch.nn.DataParallel(model).cuda()

criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.module.classifier.parameters(), lr=0.01, momentum=0.9, weight_decay = WEIGHT_DECAY)
train_acc_list, valid_acc_list = train_model(model,train_data_loader,valid_data_loader,criterion,optimizer,20, path = './checkpoint/vgg16_3')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-14-ccc1f4dee586> in <module>()
#       1 arch = 'vgg16'
#       2 num_classes = 2
# ----> 3 original_model = torchvision.models.vgg16_bn(pretrained=True)
#       4 model = FineTuneModel2(original_model, arch, num_classes)
#       5
#
# ~\Anaconda3\lib\site-packages\torchvision\models\vgg.py in vgg16_bn(pretrained, **kwargs)
#     149         pretrained (bool): If True, returns a model pre-trained on ImageNet
#     150     """
# --> 151     model = VGG(make_layers(cfg['D'], batch_norm=True), **kwargs)
#     152     if pretrained:
#     153         model.load_state_dict(model_zoo.load_url(model_urls['vgg16_bn']))
#
# ~\Anaconda3\lib\site-packages\torchvision\models\vgg.py in __init__(self, features, num_classes)
#      28         self.features = features
#      29         self.classifier = nn.Sequential(
# ---> 30             nn.Linear(512 * 7 * 7, 4096),
#      31             nn.ReLU(True),
#      32             nn.Dropout(),
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\linear.py in __init__(self, in_features, out_features, bias)
#      39         self.in_features = in_features
#      40         self.out_features = out_features
# ---> 41         self.weight = Parameter(torch.Tensor(out_features, in_features))
#      42         if bias:
#      43             self.bias = Parameter(torch.Tensor(out_features))
#
# RuntimeError: $ Torch: not enough memory: you tried to allocate 0GB. Buy new RAM! at D:\pytorch\pytorch\torch\lib\TH\THGeneral.c:246

# %% [markdown]
# # Visualization
# ## dog vs cat image

# %%
class UnNormalize(object):
    def __init__(self, mean, std):
        self.mean = mean
        self.std = std

    def __call__(self, tensor):
        """
        Args:
            tensor (Tensor): Tensor image of size (C, H, W) to be normalized.
        Returns:
            Tensor: Normalized image.
        """
        result = tensor
        for t, m, s in zip(tensor, self.mean, self.std):
            t.mul_(s).add_(m)
            # The normalize code -> t.sub_(m).div_(s)
        return tensor
     
unorm = UnNormalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))

def plot_images(tensor, num_cols=5):
    num_kernels = tensor.shape[0]
    num_rows = 1+ num_kernels // num_cols
    fig = plt.figure(figsize=(num_cols,num_rows))
    for i in range(tensor.shape[0]):
        ax1 = fig.add_subplot(num_rows,num_cols,i+1)
        img = transforms.ToPILImage()(unorm(tensor[i]))
        ax1.imshow(img)
        ax1.axis('off')
        ax1.set_xticklabels([])
        ax1.set_yticklabels([])

    plt.subplots_adjust(wspace=0.1, hspace=0.1)
    plt.savefig('dog_cat_images.pdf')
    plt.show()

# %%
img, label = next(iter(train_data_loader))
print(img.size(), label.size())
plot_images(img)
# Out:
# torch.Size([25, 3, 64, 64]) torch.Size([25])

# %%
from mpl_toolkits.axes_grid1 import ImageGrid
# from torchvision.transforms import Compose, ToPILImage, ToTensor
def imshow(axis, inp):
    """Denormalize and show"""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    print (inp)
#     transform1 = transforms.Compose([
#     ToPILImage(),
#     ToTensor()])
#     inp = transform1(inp)
    axis.imshow(torchinp)
    
def visualize_model(dataloders, model, num_cols = 4, num_images=16):
    cnt = 0
    num_kernels = num_images
    num_rows = 1+ num_kernels // num_cols
    fig = plt.figure(figsize=(num_cols,num_rows))
    for i, (inputs, labels) in enumerate(dataloders):
        if cuda_available:
            inputs, labels = Variable(inputs.cuda()), Variable(labels.cuda())
        else:
            inputs, labels = Variable(inputs), Variable(labels)

        outputs = model(inputs)
        _, preds = torch.max(outputs.data, 1)
        x = torch.FloatTensor( inputs.cpu().data.numpy() )
        for j in range(inputs.size()[0]):
            ax1 = fig.add_subplot(num_rows,num_cols,j+1)
            img = transforms.ToPILImage()(unorm(x[j]))
#             imshow(ax1,inputs[j].cpu().data)
            ax1.imshow(img)
            ax1.text(10, 210, '{}/{}'.format(preds[j], labels.data[j]), 
                    color='k', backgroundcolor='w', alpha=0.8)
            ax1.axis('off')
            cnt += 1
            if cnt == num_images:
                plt.subplots_adjust(wspace=0.1, hspace=0.1)
                plt.savefig('dog_cat_prediction.pdf')
                plt.show()  
                return 
     
visualize_model(test_data_loader, net)

# %% [markdown]
# ## wrongly predicted examples

# %%
def visualize_wronly_predicted(dataloders, model, num_cols = 4, num_images=16):
    cnt = 0
    num_kernels = num_images
    num_rows = 1+ num_kernels // num_cols
    fig = plt.figure(figsize=(num_cols,num_rows))
    for i, (inputs, labels) in enumerate(dataloders):
        if cuda_available:
            inputs, labels = Variable(inputs.cuda()), Variable(labels.cuda())
        else:
            inputs, labels = Variable(inputs), Variable(labels)

        outputs = model(inputs)
        _, preds = torch.max(outputs.data, 1)
        x = torch.FloatTensor( inputs.cpu().data.numpy() )
        for j in range(inputs.size()[0]):
            if preds[j] != labels.data[j]:
                ax1 = fig.add_subplot(num_rows,num_cols,cnt+1)
                img = transforms.ToPILImage()(unorm(x[j]))
    #             imshow(ax1,inputs[j].cpu().data)
                ax1.imshow(img)
                ax1.text(10, 210, '{}/{}'.format(preds[j], labels.data[j]), 
                        color='k', backgroundcolor='w', alpha=0.8)
                ax1.axis('off')
                cnt += 1
                if cnt == num_images:
                    plt.subplots_adjust(wspace=0.1, hspace=0.1)
                    plt.savefig('dog_cat_wrong_prediction.pdf')
                    plt.show()  
                    return 
visualize_wronly_predicted(test_data_loader, net)

# %%
def visualize_predicted_half(dataloders, model, num_cols = 4, num_images=16):
    cnt = 0
    num_kernels = num_images
    num_rows = 1+ num_kernels // num_cols
    fig = plt.figure(figsize=(num_cols*3,num_rows*3))
    soft = nn.Softmax()
    for i, (inputs, labels) in enumerate(dataloders):
        if cuda_available:
            inputs, labels = Variable(inputs.cuda()), Variable(labels.cuda())
        else:
            inputs, labels = Variable(inputs), Variable(labels)

        outputs = model(inputs)
        probs = soft(outputs)
        _, preds = torch.max(outputs.data, 1)
        x = torch.FloatTensor( inputs.cpu().data.numpy() )
        for j in range(inputs.size()[0]):
            if  probs.data[j,labels.data[j]]>0.4 and probs.data[j,labels.data[j]] <0.6:
#                 print (probs.data[j,:])
                ax1 = fig.add_subplot(num_rows,num_cols,cnt+1)
                img = transforms.ToPILImage()(unorm(x[j]))
    #             imshow(ax1,inputs[j].cpu().data)
                ax1.imshow(img)
                ax1.text(5, 50, '{}/{}/{:.2f}'.format(preds[j], labels.data[j], probs.data[j,preds[j]]), 
                        color='k', backgroundcolor='w', alpha=0.5)
                ax1.axis('off')
                cnt += 1
                if cnt == 1 :
                    img.save('half_half.png')
                if cnt == num_images:
                    plt.subplots_adjust(wspace=0.1, hspace=0.1)
                    plt.savefig('dog_cat_half_half.pdf')
                    plt.show()  
                    return 
criterion = nn.CrossEntropyLoss()

# %%
print('==> Resuming from checkpoint..')
assert os.path.isdir('checkpoint'), 'Error: no checkpoint directory found!'
#net.load_state_dict(torch.load('./checkpoint/vgg16_2', map_location='cpu'))
checkpoint = torch.load('./checkpoint/vgg16_2', map_location='cpu')
net = checkpoint['net']
best_acc = checkpoint['acc']
start_epoch = checkpoint['epoch']
# Out:
# ==> Resuming from checkpoint..
# /anaconda3/lib/python3.6/site-packages/torch/serialization.py:325: SourceChangeWarning: source code of class 'torch.nn.modules.conv.Conv2d' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /anaconda3/lib/python3.6/site-packages/torch/serialization.py:325: SourceChangeWarning: source code of class 'torch.nn.modules.pooling.MaxPool2d' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /anaconda3/lib/python3.6/site-packages/torch/serialization.py:325: SourceChangeWarning: source code of class 'torch.nn.modules.linear.Linear' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)

# %%
visualize_predicted_half(test_data_loader,net, num_cols = 2, num_images=4)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#
# /anaconda3/lib/python3.6/site-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 80000 bytes but only got 0. Skipping tag 64640
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.6/site-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 6553600 bytes but only got 0. Skipping tag 49
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.6/site-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 1050744 bytes but only got 4951. Skipping tag 51
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.6/site-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 293339136 bytes but only got 0. Skipping tag 5
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.6/site-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 293863424 bytes but only got 0. Skipping tag 5
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.6/site-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 3368026112 bytes but only got 0. Skipping tag 7
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.6/site-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 134479872 bytes but only got 0. Skipping tag 7
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.6/site-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 295698432 bytes but only got 0. Skipping tag 10
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.6/site-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 296222720 bytes but only got 0. Skipping tag 5
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.6/site-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 3300917248 bytes but only got 0. Skipping tag 7
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.6/site-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 65536 bytes but only got 0. Skipping tag 3
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.6/site-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 14745600 bytes but only got 0. Skipping tag 4
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.6/site-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 25624576 bytes but only got 0. Skipping tag 4
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.6/site-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 317718528 bytes but only got 4956. Skipping tag 4
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.6/site-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 131073 bytes but only got 4952. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.6/site-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 393216 bytes but only got 0. Skipping tag 3
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.6/site-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 287178752 bytes but only got 0. Skipping tag 5
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.6/site-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 287703040 bytes but only got 0. Skipping tag 5
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.6/site-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 131072 bytes but only got 0. Skipping tag 3
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.6/site-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 524288 bytes but only got 0. Skipping tag 4
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.6/site-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 286654464 bytes but only got 4956. Skipping tag 4
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.6/site-packages/PIL/TiffImagePlugin.py:742: UserWarning: Corrupt EXIF data.  Expecting to read 12 bytes but only got 2.
#   warnings.warn(str(msg))

# %% [markdown]
# ## Images with high probability

# %%
def visualize_high_prob(dataloders, model, num_cols = 4, num_images=16):
    cnt = 0
    num_kernels = num_images
    num_rows = 1+ num_kernels // num_cols
    fig = plt.figure(figsize=(num_cols*3,num_rows*3))
    soft = nn.Softmax()
    for i, (inputs, labels) in enumerate(dataloders):
        if cuda_available:
            inputs, labels = Variable(inputs.cuda()), Variable(labels.cuda())
        else:
            inputs, labels = Variable(inputs), Variable(labels)

        outputs = model(inputs)
        probs = soft(outputs)
        _, preds = torch.max(outputs.data, 1)
        x = torch.FloatTensor( inputs.cpu().data.numpy() )
        for j in range(inputs.size()[0]):
            if  preds[j] == labels.data[j] and probs.data[j,labels.data[j]]>0.9:
#                 print (probs.data[j,:])
                ax1 = fig.add_subplot(num_rows,num_cols,cnt+1)
                img = transforms.ToPILImage()(unorm(x[j]))
    #             imshow(ax1,inputs[j].cpu().data)
                ax1.imshow(img)
                ax1.text(5, 50, '{}/{}/{:.2f}'.format(preds[j], labels.data[j], probs.data[j,preds[j]]), 
                        color='k', backgroundcolor='w', alpha=0.5)
                ax1.axis('off')
                cnt += 1
                if cnt == 1 :
                    img.save('high_prob_correct.png')
                if cnt == num_images:
                    plt.subplots_adjust(wspace=0.1, hspace=0.1)
                    plt.savefig('dog_cat_high_prob.pdf')
                    plt.show()  
                    return

# %%
visualize_high_prob(test_data_loader,net, num_cols = 2, num_images=4)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.

# %% [markdown]
# ## Images with high probability but wrong

# %%
def visualize_high_prob_wrong(dataloders, model, num_cols = 4, num_images=16):
    cnt = 0
    num_kernels = num_images
    num_rows = 1+ num_kernels // num_cols
    fig = plt.figure(figsize=(num_cols*3,num_rows*3))
    soft = nn.Softmax()
    for i, (inputs, labels) in enumerate(dataloders):
        if cuda_available:
            inputs, labels = Variable(inputs.cuda()), Variable(labels.cuda())
        else:
            inputs, labels = Variable(inputs), Variable(labels)

        outputs = model(inputs)
        probs = soft(outputs)
        _, preds = torch.max(outputs.data, 1)
        x = torch.FloatTensor( inputs.cpu().data.numpy() )
        for j in range(inputs.size()[0]):
            if  preds[j] != labels.data[j] and probs.data[j,preds[j]]>0.9:
#                 print (probs.data[j,:])
                ax1 = fig.add_subplot(num_rows,num_cols,cnt+1)
                img = transforms.ToPILImage()(unorm(x[j]))
    #             imshow(ax1,inputs[j].cpu().data)
                ax1.imshow(img)
                ax1.text(5, 50, '{}/{}/{:.2f}'.format(preds[j], labels.data[j], probs.data[j,preds[j]]), 
                        color='k', backgroundcolor='w', alpha=0.5)
                ax1.axis('off')
                cnt += 1
                if cnt == 1 :
                    img.save('high_prob_wrong.png')
                if cnt == num_images:
                    plt.subplots_adjust(wspace=0.1, hspace=0.1)
                    plt.savefig('dog_cat_high_prob_wrong.pdf')
                    plt.show()  
                    return

# %%
visualize_high_prob_wrong(test_data_loader,net, num_cols = 2, num_images=4)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
